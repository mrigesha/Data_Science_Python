# %%
import pandas as pd
import numpy as np
import xlrd

# %%
df = pd.read_excel("C:/Users/MRIGESHA/Desktop/EXCELR/Assignments/Clustering/EastWestAirlines.xlsx", sheet_name = 'data')

# %%
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
# Normalization

def Norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return(x)

# %%
df_norm = Norm_func(df.iloc[:,1:])

# %%
df_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# Since number of rows are high hence Hierarchical clustering is not suggested. 
# Howwever as per question we are performing the same

#########     Hierarchical Clustering(Aglomerative)            ##########

# %%
# Create Dendrogram
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt

plt.figure(figsize = (10,7))
dendrogram = sch.dendrogram(sch.linkage(df_norm, method = 'ward'))

# %%
# create Clusters
hc = AgglomerativeClustering(n_clusters = 5, affinity = 'euclidean', linkage = 'single')

# %%
y_hc = hc.fit_predict(df_norm)

# %%
y_hc
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
df_hc = df.copy()

# %%
df_hc['cluster_id'] = y_hc

# %%
df_hc
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df_hc.iloc[:,1:].groupby(df_hc.cluster_id).mean()
# Out:
#                   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# cluster_id
# 0            59807.839555   87.602462   1.705322   1.013900   1.008737
# 1            97125.211773  240.345737   2.664411   1.015562   1.015562
# 2           160114.000000  500.000000   1.000000   1.000000   1.000000
# 3             8557.000000    0.000000   1.000000   1.000000   1.000000
# 4            15835.000000    0.000000   2.000000   1.000000   5.000000
#
#               Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# cluster_id
# 0            10227.689039     9.142971         226.292295         0.652502
# 1            28703.769959    15.742219         837.970230         2.566982
# 2            71954.000000    86.000000       30817.000000        53.000000
# 3           200622.000000     5.000000         622.000000         3.000000
# 4           112171.000000    16.000000           0.000000         0.000000
#
#             Days_since_enroll  Award?
# cluster_id
# ...

# %%
# Plot Clusters
plt.figure(figsize=(10, 7))  
plt.scatter(df_hc['cluster_id'],df_hc['Balance'], c=hc.labels_)

# %%
# K Means
from scipy.spatial.distance import cdist
from sklearn.cluster import KMeans

# %%
# create Elbow Curve to identify No. of K
# inertia_ -- This will calculare WCSS(Withib Cluster sum of square of distance)    
wcss = []

for i in range(1,11):
    kmeans = KMeans(n_clusters = i, random_state = 0)
    kmeans.fit(df_norm)
    wcss.append(kmeans.inertia_)
    
plt.plot(range(1,11),wcss)

# %%
# create clusters
model = KMeans(n_clusters = 5)
model.fit(df_norm)
model.labels_
# Out:
# array([4, 4, 4, ..., 3, 1, 1])

# %%
df_kmeans = df.copy()

# %%
md = pd.Series(model.labels_)
df_kmeans['Cluster'] = md

# %%
df_kmeans
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df_kmeans.iloc[:,1:].groupby(df_kmeans.Cluster).mean()
# Out:
#                Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# Cluster
# 0         83529.153046  290.453195   1.156018   1.032689   1.008915
# 1         33097.301357   94.131783   1.070736   1.016473   1.006783
# 2        118297.325243   73.467638   3.584142   1.001618   1.022654
# 3        108317.387376  198.336634   3.915842   1.001238   1.025990
# 4         49921.633641   89.903226   1.122120   1.019585   1.001152
#
#           Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# Cluster
# 0         8850.395245    10.476969        1030.112927         3.148588
# 1         3244.520349     6.173450         212.850775         0.603682
# 2        31384.393204    17.233010         224.100324         0.627832
# 3        45609.657178    20.201733         713.728960         2.142327
# 4         3467.074885     6.913594         243.834101         0.728111
#
#          Days_since_enroll  Award?  Cluster
# Cluster
# 0              4338.867756     1.0        0
# ...

# %%
# Plot Clusters
plt.figure(figsize=(10, 7))  
plt.scatter(df_kmeans['Cluster'],df_kmeans['Balance'], c=model.labels_)

# %%
# DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %%
dbscan = DBSCAN(eps=0.8, min_samples=13)
dbscan.fit(df_norm)
# Out:
# DBSCAN(eps=0.8, min_samples=13)

# %%
#Noisy samples are given the label -1.
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
cl=pd.DataFrame(dbscan.labels_,columns=['cluster'])

# %%
df_dbscan = df.copy()
df_dbscan['Cluster'] = cl
df_dbscan
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df_dbscan['Cluster'] == -1
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3994    False
# 3995    False
# 3996    False
# 3997    False
# 3998    False
# Name: Cluster, Length: 3999, dtype: bool

# %%
df_dbscan_drop_index = df_dbscan[df_dbscan['Cluster'] == -1].index

# %%
df_dbscan.drop(df_dbscan_drop_index, inplace = True)

# %%
df_dbscan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3999 entries, 0 to 3998
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
#  12  Cluster            3999 non-null   int64
# dtypes: int64(13)
# memory usage: 437.4 KB

# %%
df_dbscan.iloc[:,1:].groupby(df_dbscan.Cluster).mean()
# Out:
#               Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# Cluster
# 0        59807.839555   87.602462   1.705322    1.01390   1.008737
# 1        97053.051317  240.196489   2.661715    1.01553   1.018231
#
#           Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# Cluster
# 0        10227.689039     9.142971         226.292295         0.652502
# 1        28905.414585    15.782579         857.501013         2.599595
#
#          Days_since_enroll  Award?  Cluster
# Cluster
# 0              3820.652105     0.0      0.0
# 1              4625.062120     1.0      1.0

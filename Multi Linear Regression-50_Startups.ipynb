# %%
import numpy as np
import pandas as pd
from statsmodels.graphics.regressionplots import influence_plot
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/MRIGESHA/Desktop/EXCELR/Assignments/Multi Linear Regression/50_Startups.csv")

# %%
df.shape
# Out:
# (50, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.State.unique()
# Out:
# array(['New York', 'California', 'Florida'], dtype=object)

# %%
df['State'] = df['State'].astype('category')

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [R&D Spend, Administration, Marketing Spend, State, Profit]
# Index: []

# %%
df.dtypes
# Out:
# R&D Spend           float64
# Administration      float64
# Marketing Spend     float64
# State              category
# Profit              float64
# dtype: object

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002D91E97EB20>,
# ...
#       dtype=object)

# %%
df.boxplot()

# %%
sns.boxplot(x = 'State', y = 'Profit', data = df)
plt.show()

# New York city has outliers

# %%
df.corr()
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
import seaborn as sns
sns.set_style(style = 'darkgrid')
sns.pairplot(df1)

# %%
df.columns = df.columns.str.replace(' ', '')

# %%
df
# Out:
#      R&DSpend  Administration  MarketingSpend       State     Profit
# 0   165349.20       136897.80       471784.10    New York  192261.83
# 1   162597.70       151377.59       443898.53  California  191792.06
# 2   153441.51       101145.55       407934.54     Florida  191050.39
# 3   144372.41       118671.85       383199.62    New York  182901.99
# 4   142107.34        91391.77       366168.42     Florida  166187.94
# 5   131876.90        99814.71       362861.36    New York  156991.12
# 6   134615.46       147198.87       127716.82  California  156122.51
# 7   130298.13       145530.06       323876.68     Florida  155752.60
# 8   120542.52       148718.95       311613.29    New York  152211.77
# 9   123334.88       108679.17       304981.62  California  149759.96
# 10  101913.08       110594.11       229160.95     Florida  146121.95
# 11  100671.96        91790.61       249744.55  California  144259.40
# 12   93863.75       127320.38       249839.44     Florida  141585.52
# ...

# %%
# spliting Dataset in Dependent & Independent Variables
X = df.iloc[:, :-1]
y = df.iloc[:, 3]

# %%
X_dum = pd.get_dummies(X)
y_dum = pd.get_dummies(y)

# %%
X_val = X_dum.iloc[:,:].values
y_val = y_dum.iloc[:,:].values

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(X_val,y_val,train_size=0.7,random_state=0)
x_train
# Out:
# array([[1.3029813e+05, 1.4553006e+05, 3.2387668e+05, 0.0000000e+00,
#         1.0000000e+00, 0.0000000e+00],
#        [1.1994324e+05, 1.5654742e+05, 2.5651292e+05, 0.0000000e+00,
#         1.0000000e+00, 0.0000000e+00],
#        [1.0002300e+03, 1.2415304e+05, 1.9039300e+03, 0.0000000e+00,
#         0.0000000e+00, 1.0000000e+00],
#        [5.4205000e+02, 5.1743150e+04, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 1.0000000e+00],
#        [6.5605480e+04, 1.5303206e+05, 1.0713838e+05, 0.0000000e+00,
#         0.0000000e+00, 1.0000000e+00],
#        [1.1452361e+05, 1.2261684e+05, 2.6177623e+05, 0.0000000e+00,
#         0.0000000e+00, 1.0000000e+00],
#        [6.1994480e+04, 1.1564128e+05, 9.1131240e+04, 0.0000000e+00,
#         1.0000000e+00, 0.0000000e+00],
#        [6.3408860e+04, 1.2921961e+05, 4.6085250e+04, 1.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [7.8013110e+04, 1.2159755e+05, 2.6434606e+05, 1.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
x_train = sc_X.fit_transform(x_train)
x_test = sc_X.transform(x_test)
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train)
y_test = sc_y.fit_transform(y_test)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train,y_train)
print('Model has been trained successfully')
# Out:
# Model has been trained successfully

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([[-0.8660254 ,  2.        , -0.76870611],
#        [ 1.15470054, -0.5       , -0.76870611],
#        [-0.8660254 ,  2.        , -0.76870611],
#        [-0.8660254 ,  2.        , -0.76870611],
#        [-0.8660254 ,  2.        , -0.76870611],
#        [-0.8660254 , -0.5       ,  1.30088727],
#        [-0.8660254 , -0.5       ,  1.30088727],
#        [-0.8660254 , -0.5       ,  1.30088727],
#        [-0.8660254 ,  2.        , -0.76870611],
#        [-0.8660254 ,  2.        , -0.76870611],
#        [-0.8660254 ,  2.        , -0.76870611],
#        [-0.8660254 , -0.5       ,  1.30088727],
#        [-0.8660254 ,  2.        , -0.76870611],
#        [ 1.15470054, -0.5       , -0.76870611],
#        [-0.8660254 ,  2.        , -0.76870611]])

# %%
testing_data_model_score = model.score(x_test, y_test)
print("Model Score/Performance on Testing data",testing_data_model_score)

training_data_model_score = model.score(x_train, y_train)
print("Model Score/Performance on Training data",training_data_model_score)
# Out:
# Model Score/Performance on Testing data 0.48044776992505894
# Model Score/Performance on Training data 1.0

# %% [markdown]
# ## from sklearn.metrics import r2_score
#
# r2Score = r2_score(y_pred, y_test)
# print("R2 score of model is :" ,r2Score*100)

# %%
df2 =df.rename({'R&DSpend':'RDS','Administration':'ADMS','MarketingSpend':'MKTS'},axis=1)
df2
# Out:
#           RDS       ADMS       MKTS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
import statsmodels.formula.api as smf
import statsmodels.api as sm
model_ols_1=smf.ols("Profit~RDS+ADMS+MKTS",data=df2).fit()
model_ols_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Sun, 08 May 2022   Prob (F-statistic):           4.53e-30
# Time:                        07:05:37   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.012e+04   6572.353      7.626      0.000    3.69e+04    6.34e+04
# ...

# %%
import statsmodels.formula.api as smf
import statsmodels.api as sm
model_ols_2=smf.ols("Profit~RDS",data=df2).fit()
model_ols_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     849.8
# Date:                Sun, 08 May 2022   Prob (F-statistic):           3.50e-32
# Time:                        07:06:46   Log-Likelihood:                -527.44
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      48   BIC:                             1063.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   4.903e+04   2537.897     19.320      0.000    4.39e+04    5.41e+04
# ...

# %%
import statsmodels.formula.api as smf
import statsmodels.api as sm
model_ols_3=smf.ols("Profit~ADMS",data=df2).fit()
model_ols_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     2.015
# Date:                Sun, 08 May 2022   Prob (F-statistic):              0.162
# Time:                        07:07:10   Log-Likelihood:                -599.63
# No. Observations:                  50   AIC:                             1203.
# Df Residuals:                      48   BIC:                             1207.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7.697e+04   2.53e+04      3.040      0.004    2.61e+04    1.28e+05
# ...

# %%
# 1) Collinearity Problem Check
# Calculate VIF = 1/(1-Rsquare) for all independent variables

rsq_r=smf.ols("RDS~ADMS+MKTS",data=df2).fit().rsquared
vif_r=1/(1-rsq_r)

rsq_a=smf.ols("ADMS~RDS+MKTS",data=df2).fit().rsquared
vif_a=1/(1-rsq_a)

rsq_m=smf.ols("MKTS~RDS+ADMS",data=df2).fit().rsquared
vif_m=1/(1-rsq_m)

# Putting the values in Dataframe format
d1={'Variables':['RDS','ADMS','MKTS'],'Vif':[vif_r,vif_a,vif_m]}
Vif_df=pd.DataFrame(d1)
Vif_df
# Out:
#   Variables       Vif
# 0       RDS  2.468903
# 1      ADMS  1.175091
# 2      MKTS  2.326773

# %%
# 2) Residual Analysis
# Test for Normality of Residuals (Q-Q Plot) using residual model (model.resid)

sm.qqplot(model_ols_1.resid,line='q')
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
import statsmodels.api as sm
from statsmodels.graphics.regressionplots import influence_plot
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model_ols_1,'RDS',fig=fig)
plt.show()

# %%
# 1. Cook's Distance: If Cook's distance > 1, then it's an outlier
# Get influencers using cook's distance
(c,_)=model_ols_1.get_influence().cooks_distance
c
# Out:
# array([3.21825244e-05, 3.27591036e-03, 3.23842699e-02, 2.17206555e-02,
#        1.44833032e-02, 1.17158463e-02, 2.91766303e-03, 3.56513444e-03,
#        4.04303948e-05, 4.86758017e-03, 1.51064757e-02, 1.63564959e-02,
#        1.15516625e-02, 4.01422811e-03, 6.12934253e-02, 3.40013448e-02,
#        8.33556413e-03, 3.30534399e-03, 2.16819303e-03, 4.07440577e-02,
#        4.25137222e-04, 1.09844352e-02, 2.91768000e-03, 2.76030254e-04,
#        5.04643588e-03, 3.00074623e-03, 3.41957068e-03, 2.98396413e-02,
#        1.31590664e-03, 1.25992620e-04, 4.18505125e-05, 9.27434786e-06,
#        7.08656521e-04, 1.28122674e-04, 2.09815032e-02, 6.69508674e-03,
#        5.55314705e-02, 6.55050578e-05, 5.61547311e-02, 1.54279607e-03,
#        1.84850929e-03, 1.97578066e-03, 1.36089280e-04, 2.05553171e-02,
#        1.23156041e-04, 9.03234206e-02, 5.45303387e-02, 5.33885616e-03,
#        1.90527441e-01, 2.88082293e-01])

# %%
# Plot the influencers using the stem plot
fig=plt.figure(figsize=(20,7))
plt.stem(np.arange(len(df2)),np.round(c,5))
plt.xlabel('Row Index')
plt.ylabel('Cooks Distance')
plt.show()
# Out:
# <ipython-input-125-e4a93290e4d6>:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(np.arange(len(df2)),np.round(c,5))

# %%
# Index and value of influencer where C>0.5
np.argmax(c) , np.max(c)
# Out:
# (49, 0.28808229275432673)

# %%
# 2. Leverage Value using High Influence Points : Points beyond Leverage_cutoff value are influencers
influence_plot(model_ols_1)
plt.show()

# %%
# Leverage Cuttoff Value = 3*(k+1)/n ; k = no.of features/columns & n = no. of datapoints
k=df2.shape[1]
n=df2.shape[0]
leverage_cutoff = (3*(k+1))/n
leverage_cutoff
# Out:
# 0.36

# %%
df2[df2.index.isin([49])]
# Out:
#     RDS      ADMS      MKTS       State   Profit
# 49  0.0  116983.8  45173.06  California  14681.4

# %%
# Discard the data points which are influencers and reassign the row number (reset_index(drop=True))
df2=df2.drop(df2.index[[49]],axis=0).reset_index(drop=True)
df2
# Out:
#           RDS       ADMS       MKTS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
while np.max(c)>0.5 :
    model=smf.ols("Profit~RDS+ADMS+MKTS",data=df2).fit()
    (c,_)=model.get_influence().cooks_distance
    c
    np.argmax(c) , np.max(c)
    df2=df2.drop(df2.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
    df2
else:
    final_model=smf.ols("Profit~RDS+ADMS+MKTS",data=df2).fit()
    final_model.rsquared , final_model.aic
    print("Thus model accuracy is improved to",final_model.rsquared)
# Out:
# Thus model accuracy is improved to 0.9613162435129847

# %%
# say New data for prediction is
new_data=pd.DataFrame({'RDS':70000,"ADMS":90000,"MKTS":140000},index=[0])
new_data
# Out:
#      RDS   ADMS    MKTS
# 0  70000  90000  140000

# %%
# Manual Prediction of Price
final_model.predict(new_data)
# Out:
# 0    108727.154753
# dtype: float64

# %%
# Automatic Prediction of Price with 90.02% accurcy
pred_y=final_model.predict(df2)
pred_y
# Out:
# 0     190716.676999
# 1     187537.122227
# 2     180575.526396
# 3     172461.144642
# 4     170863.486721
# 5     162582.583177
# 6     157741.338633
# 7     159347.735318
# 8     151328.826941
# 9     154236.846778
# 10    135507.792682
# 11    135472.855621
# 12    129355.599449
# 13    127780.129139
# 14    149295.404796
# 15    145937.941975
# 16    117437.627921
# 17    130408.626295
# 18    129129.234457
# 19    116641.003121
# 20    117097.731866
# 21    117911.019038
# 22    115248.217796
# 23    110603.139045
# 24    114051.073877
# 25    103398.054385
# 26    111547.638935
# 27    114916.165026
# 28    103027.229434
# 29    103057.621761
# 30    100656.410227
# 31     99088.213693
# 32    100325.741335
# 33     98962.303136
# 34     90552.307809
# 35     91709.288672
# 36     77080.554255
# 37     90722.503244
# 38     71433.021956
# 39     85147.375646
# 40     76625.510303
# 41     76492.145175
# 42     72492.394974
# 43     62592.049718
# 44     67025.731107
# ...
